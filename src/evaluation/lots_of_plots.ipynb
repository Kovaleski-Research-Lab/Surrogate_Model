# %%
# %matplotlib widget

import os
import sys
import matplotlib.pyplot as plt
import torch
torch.multiprocessing.set_sharing_strategy('file_system')

## methods for evaluating training results
sys.path.append("../core")
from model import CAI_Model

## methods for evaluating resims
sys.path.append(os.path.abspath("/develop/code/cai_2023/evaluation"))
import eval_methods as em

sys.path.append(os.path.abspath("/develop/code/cai_2023/resim"))
import launch_resim as launch

path_results = "/develop/results"
# Out:
# Global seed set to 1337

# %% [markdown]
# ## getting lots of plots

# %%
all_loss = em.gather_all_loss(path_results, "model_encoder_tuning", backbone="resnet18")
len(all_loss)
# Out:
# num folders found: 250
# num with loss: 250
# 250

# %%
lr_list = []
for result in all_loss:
    lr = result['lr']
    if lr not in lr_list:
        lr_list.append(lr)
lr_list.sort()
print(f"we have {len(lr_list)} learning rates in {len(all_loss)} folders.")
# Out:
# we have 10 learning rates in 250 folders.

# %%
all_gamma, all_delta = [], []

min_list = [0, 0, 0, 2, 2]
max_list = [10, 100, 10, 6, 8]

def grab_loss(result):

    loss = result['loss']
    loss.keys()
    title = l_string +  f": ({result['alpha']} {result['beta']} {result['delta']} {result['gamma']}) " + "\n" + result['title'].replace(path_results,"").replace("/","") + " lr=" + str(result['lr'])
    em.plot_loss(loss, title, min_list, max_list)
    
    return loss, title

#for result in all_loss:
    
l_string = r'($\alpha$' + " " + r'$\beta$' + " " + r'$\delta$' + " " + r'$\gamma$)'

# %%
plt.close("all")

for result in all_loss:
    if result['lr'] == lr_list[0]:
        grab_loss(result)
# Out:
# /develop/code/cai_2023/evaluation/eval_methods.py:114: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(2, int((len(loss.keys()) - 1)/2), figsize = (12, 4.5))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")

for result in all_loss:
    if result['lr'] == lr_list[1]:
        grab_loss(result)

# %%
plt.close("all")

for result in all_loss:
    if result['lr'] == lr_list[2]:
        grab_loss(result)

# %%
plt.close("all")

for result in all_loss:
    if result['lr'] == lr_list[3]:
        grab_loss(result)

# %%
plt.close("all")

for result in all_loss:
    if result['lr'] == lr_list[4]:
        grab_loss(result)

# %%
plt.close("all")

for result in all_loss:
    if result['lr'] == lr_list[5]:
        grab_loss(result)

# %%
plt.close("all")

for result in all_loss:
    if result['lr'] == lr_list[6]:
        grab_loss(result)

# %%
plt.close("all")

for result in all_loss:
    if result['lr'] == lr_list[7]:
        grab_loss(result)

# %%
plt.close("all")

for result in all_loss:
    if result['lr'] == lr_list[8]:
        grab_loss(result)

# %%
plt.close("all")

for result in all_loss:
    if result['lr'] == lr_list[9]:
        grab_loss(result)
